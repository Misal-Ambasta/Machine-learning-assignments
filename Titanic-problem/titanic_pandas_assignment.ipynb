# %%
import pandas as pd

# %%
df = pd.read_csv("titanic_train.csv")
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #### Column summary
# Produce a summary table listing: column name, dtype, # missing, # unique values. Sort it by # missing descending.

# %%
summary = pd.DataFrame({
    "columns": df.columns,
    "data_types": df.dtypes.values,
    "# missing": df.isnull().sum().values,
    "# unique values": df.nunique().values
})
summary = summary.sort_values(by="# missing", ascending=False)
summary
# Out:
#         columns data_types  # missing  # unique values
# 10        Cabin     object        687              147
# 5           Age    float64        177               88
# 11     Embarked     object          2                3
# 0   PassengerId      int64          0              891
# 3          Name     object          0              891
# 2        Pclass      int64          0                3
# 1      Survived      int64          0                2
# 4           Sex     object          0                2
# 7         Parch      int64          0                7
# 6         SibSp      int64          0                7
# 9          Fare    float64          0              248
# 8        Ticket     object          0              681

# %% [markdown]
# #### Value counts & proportions
# For Pclass, Gender, and Embarked, show value counts and percentages (as a DataFrame)

# %%
summaryPclass = pd.DataFrame({
    "counts": df["Pclass"].value_counts(),
    "percentages": df["Pclass"].value_counts(normalize=True) * 100
})


summaryPclass
# Out:
#         counts  percentages
# Pclass
# 3          491    55.106622
# 1          216    24.242424
# 2          184    20.650954

# %%
summaryGender = pd.DataFrame({
    "counts": df["Sex"].value_counts(),
    "percentages": df["Sex"].value_counts(normalize=True) * 100
})
summaryGender
# Out:
#         counts  percentages
# Sex
# male       577    64.758698
# female     314    35.241302

# %%
summaryEmbarked = pd.DataFrame({
    "counts": df["Embarked"].value_counts(),
    "percentages": df["Embarked"].value_counts(normalize=True) * 100
})
summaryEmbarked
# Out:
#           counts  percentages
# Embarked
# S            644    72.440945
# C            168    18.897638
# Q             77     8.661417

# %% [markdown]
# #### Select & filter
#  Create a DataFrame female_firstclass_over_30 containing female passengers in 1st class older than 30. Show the top 10 rows sorted by Fare desc.

# %%
female_firstclass_over_30 = df[(df['Sex']== 'female') & (df['Pclass'] == 1) & (df['Age'] > 30)]
female_firstclass_over_30 = female_firstclass_over_30.sort_values(by='Fare', ascending=False)
female_firstclass_over_30.head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259         1       1
# 299          300         1       1
# 716          717         1       1
# 380          381         1       1
# 779          780         1       1
# 318          319         1       1
# 856          857         1       1
# 268          269         1       1
# 609          610         1       1
# 195          196         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 258                                   Ward, Miss. Anna  female  35.0      0
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 716                      Endres, Miss. Caroline Louise  female  38.0      0
# 380                              Bidois, Miss. Rosalie  female  42.0      0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 318                           Wick, Miss. Mary Natalie  female  31.0      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 609                          Shutes, Miss. Elizabeth W  female  40.0      0
# 195                               Lurette, Miss. Elise  female  58.0      0
#
#      Parch    Ticket      Fare    Cabin Embarked
# 258      0  PC 17755  512.3292      NaN        C
# 299      1  PC 17558  247.5208  B58 B60        C
# 716      0  PC 17757  227.5250      C45        C
# 380      0  PC 17757  227.5250      NaN        C
# 779      1     24160  211.3375       B3        S
# 318      2     36928  164.8667       C7        S
# 856      1     36928  164.8667      NaN        S
# 268      1  PC 17582  153.4625     C125        S
# 609      0  PC 17582  153.4625     C125        S
# 195      0  PC 17569  146.5208      B80        C

# %% [markdown]
# #### Basic aggregations
# Compute: mean/median/mode of Age (ignore missing), mean Fare per Pclass, survival rate (mean of Survived) overall and by Gender.

# %%
dfData = pd.DataFrame({
    "mean - Age": df['Age'].mean(),
    "median - Age": df['Age'].median(),
    "mode - Age": df['Age'].mode(),
    "mean - Fare": df['Fare'].mean(),
    "median - Fare": df['Fare'].median(),
    "mode - Fare": df['Fare'].mode(),
    "mean - Survived": df['Survived'].mean(),
})
dfData
# Out:
#    mean - Age  median - Age  mode - Age  mean - Fare  median - Fare  \
# 0   29.699118          28.0        24.0    32.204208        14.4542
#
#    mode - Fare  mean - Survived
# 0         8.05         0.383838

# %% [markdown]
# ## Part B — Intermediate

# %% [markdown]
# ### Missing value imputation
# Impute missing Age values using median age grouped by Pclass and Gender (e.g., fill Age with the median age of people in the same Pclass and Gender). Create a new column Age_imputed. Show before/after missing counts.

# %%
Age_imputed = df.groupby(['Pclass', 'Sex'])['Age'].transform(lambda x: x.fillna(x.median()))
df['Age_imputed'] = Age_imputed
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_imputed
# 0      0         A/5 21171   7.2500   NaN        S         22.0
# 1      0          PC 17599  71.2833   C85        C         38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         26.0
# 3      0            113803  53.1000  C123        S         35.0
# 4      0            373450   8.0500   NaN        S         35.0

# %% [markdown]
# #### Feature extraction from text
# Extract Title (e.g., Mr, Mrs, Miss, Master, etc.) from the Name column into a new column Title. Show the counts for each title.

# %%
titleCount = df['Name'].str.extract(r",\s*([^\.]+)\.").value_counts()
titleCount
# Out:
# 0
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# Capt              1
# Lady              1
# Don               1
# Jonkheer          1
# Mme               1
# Ms                1
# Sir               1
# the Countess      1
# Name: count, dtype: int64

# %% [markdown]
# #### Family size & new feature (5 pts)
# Create FamilySize = SibSp + Parch + 1. Create IsAlone boolean (True if FamilySize==1). Show survival rate by IsAlone.

# %%
FamilySize = df['SibSp'] + df['Parch'] + 1
IsAlone = FamilySize == 1
df['FamilySize'] = FamilySize
df['IsAlone'] = IsAlone
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_imputed  FamilySize  \
# 0      0         A/5 21171   7.2500   NaN        S         22.0           2
# 1      0          PC 17599  71.2833   C85        C         38.0           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S         26.0           1
# 3      0            113803  53.1000  C123        S         35.0           2
# 4      0            373450   8.0500   NaN        S         35.0           1
#
#    IsAlone
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True

# %% [markdown]
# #### Pivot table and multi-index groupby
# Produce a pivot table showing survival rate indexed by Pclass (rows) and Gender (columns). Then produce a groupby that shows average Fare and Age_imputed for Pclass, Embarked.

# %%
pd.pivot_table(
    df,
    values='Survived',
    columns='Sex',
    index='Pclass',
    aggfunc='mean'
)
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
df.groupby(["Pclass", "Embarked"])[["Fare", "Age_imputed"]].mean()
# Out:
#                        Fare  Age_imputed
# Pclass Embarked
# 1      C         104.718529    37.988235
#        Q          90.000000    38.500000
#        S          70.364862    38.271024
# 2      C          25.358335    23.617647
#        Q          12.350000    38.333333
#        S          20.327439    30.355671
# 3      C          11.214083    21.983636
#        Q          11.183393    24.194444
#        S          14.644083    25.453258

# %% [markdown]
# #### String cleaning & parsing
#
# Clean Cabin column: replace missing cabins with 'Unknown'. Extract cabin letter (first character of cabin string) into CabinDeck (if multiple cabins listed, take first). Show survival rate by CabinDeck.

# %%
df['Cabin'] = df['Cabin'].fillna('Unknown')
df['CabinDeck'] = df['Cabin'].str[0]
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  Age_imputed  \
# 0      0         A/5 21171   7.2500  Unknown        S         22.0
# 1      0          PC 17599  71.2833      C85        C         38.0
# 2      0  STON/O2. 3101282   7.9250  Unknown        S         26.0
# 3      0            113803  53.1000     C123        S         35.0
# 4      0            373450   8.0500  Unknown        S         35.0
#
#    FamilySize  IsAlone CabinDeck
# 0           2    False         U
# 1           2    False         C
# 2           1     True         U
# 3           2    False         C
# 4           1     True         U

# %% [markdown]
# ## Part C — Advanced

# %% [markdown]
# #### Advanced joins / merges
# Create a small lookup DataFrame ticket_counts with Ticket and how many times that ticket appears (ticket frequency). Merge this back into df as TicketCount. Show top 10 tickets by TicketCount.

# %%
ticket_counts = df['Ticket'].value_counts().reset_index()
ticket_counts.columns = ['Ticket', 'TicketCount']
df = df.merge(ticket_counts, on='Ticket', how='left')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  Age_imputed  \
# 0      0         A/5 21171   7.2500  Unknown        S         22.0
# 1      0          PC 17599  71.2833      C85        C         38.0
# 2      0  STON/O2. 3101282   7.9250  Unknown        S         26.0
# 3      0            113803  53.1000     C123        S         35.0
# 4      0            373450   8.0500  Unknown        S         35.0
#
#    FamilySize  IsAlone CabinDeck  TicketCount
# 0           2    False         U            1
# 1           2    False         C            1
# 2           1     True         U            1
# 3           2    False         C            2
# 4           1     True         U            1

# %%
df[['Ticket', 'TicketCount']].drop_duplicates().sort_values(
    by='TicketCount', ascending=False
).head(10)
# Out:
#            Ticket  TicketCount
# 13         347082            7
# 74           1601            7
# 159      CA. 2343            7
# 50        3101295            6
# 59        CA 2144            6
# 63         347088            6
# 16         382652            5
# 72   S.O.C. 14879            5
# 390        113760            4
# 27          19950            4
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['TicketCount'].plot(kind='hist', bins=20, title='TicketCount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['TicketCount'].plot(kind='line', figsize=(8, 4), title='TicketCount')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ### Outlier detection & handling
# Identify passengers with Fare in the top 1% (by value). Create a flag column Fare_outlier. Replace those Fare values with the 99th percentile value and show the effect on mean/median Fare.

# %%
fare_99 = df['Fare'].quantile(0.99)
df['Fare_outlier'] = df['Fare'] > fare_99
df['Fare_capped'] = df['Fare'].clip(upper=fare_99)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  Age_imputed  \
# 0      0         A/5 21171   7.2500  Unknown        S         22.0
# 1      0          PC 17599  71.2833      C85        C         38.0
# 2      0  STON/O2. 3101282   7.9250  Unknown        S         26.0
# 3      0            113803  53.1000     C123        S         35.0
# 4      0            373450   8.0500  Unknown        S         35.0
#
#    FamilySize  IsAlone CabinDeck  TicketCount  Fare_outlier  Fare_capped
# 0           2    False         U            1         False       7.2500
# 1           2    False         C            1         False      71.2833
# 2           1     True         U            1         False       7.9250
# 3           2    False         C            2         False      53.1000
# 4           1     True         U            1         False       8.0500

# %%
pd.DataFrame({
    "Original": [df['Fare'].mean(), df['Fare'].median()],
    "Capped": [df['Fare_capped'].mean(), df['Fare_capped'].median()]
}, index=["Mean", "Median"])
# Out:
#          Original     Capped
# Mean    32.204208  31.224767
# Median  14.454200  14.454200

# %% [markdown]
# #### Complex aggregation with apply
# Write a function that categorizes age groups: Child (<12), Teen (12–17), YoungAdult (18–30), Adult (31–60), Senior (>60). Use .apply or pd.cut to create AgeGroup. Show survival rate for each AgeGroup by Gender.

# %%
def categorize_age(age):
  if age < 12:
    return "Child"
  elif age < 18:
    return "Teen"
  elif age < 31:
    return "YoungAdult"
  elif age < 61:
    return "Adult"
  else:
    return "Senior"

# %%
df['AgeGroup'] = df['Age'].apply(categorize_age)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  Age_imputed  \
# 0      0         A/5 21171   7.2500  Unknown        S         22.0
# 1      0          PC 17599  71.2833      C85        C         38.0
# 2      0  STON/O2. 3101282   7.9250  Unknown        S         26.0
# 3      0            113803  53.1000     C123        S         35.0
# 4      0            373450   8.0500  Unknown        S         35.0
#
#    FamilySize  IsAlone CabinDeck  TicketCount  Fare_outlier  Fare_capped  \
# 0           2    False         U            1         False       7.2500
# 1           2    False         C            1         False      71.2833
# 2           1     True         U            1         False       7.9250
# 3           2    False         C            2         False      53.1000
# 4           1     True         U            1         False       8.0500
#
#      AgeGroup
# 0  YoungAdult
# 1       Adult
# 2  YoungAdult
# 3       Adult
# 4       Adult

# %%
df.pivot_table(
    values='Survived',
    index='AgeGroup',
    columns='Sex',
    aggfunc='mean'
)
# Out:
# Sex           female      male
# AgeGroup
# Adult       0.808081  0.214286
# Child       0.593750  0.555556
# Senior      0.696429  0.125874
# Teen        0.826087  0.136364
# YoungAdult  0.730769  0.149485
